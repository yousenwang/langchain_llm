# %%
import requests

r = requests.post(
    url='http://127.0.0.1:8006/sentences_similarity',
    json = {
        "query_sentences": [
            "How may I call you?",
            "How old is your professor?"
        ],
        "passage_sentences": [
            "What is your name?",
            "How old is your professor?"
        ],
        "lang": "us_en"
    }
    )

# print(r.content)

# %%
json.loads(r.content.decode('utf-8'))
# Out:
# {'similarity': [[0.6083557605743408, 0.4624160826206207],
#   [0.5215487480163574, 1.0000001192092896]]}

# %%
r_cn = requests.post(
    url='http://127.0.0.1:8006/sentences_similarity',
    json = {
        "query_sentences": [
            "你叫甚麼名字?",
            "你的教授幾歲?"
        ],
        "passage_sentences": [
            "我該如何稱呼您?",
            "你的教授幾歲?"
        ],
        "lang": "tw_cn"
    }
    )

# print(r.content)

# %%
json.loads(r_cn.content.decode('utf-8'))
# Out:
# {'similarity': [[0.47843003273010254, 0.39702120423316956],
#   [0.2338709831237793, 1.0000001192092896]]}

# %%
import requests

r = requests.post(
    url='http://127.0.0.1:8006/sentences_similarity',
    json = {
        "user_input": "自动核准后还需要进行单号提交吗?",
        "lang": "us_en"
    }
    )
# r = requests.get('http://127.0.0.1:8000')

# print(r.content)

# %%
# !nvidia-smi
# Out:
# Mon Sep 11 09:29:41 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A40                     Off | 00000000:AF:00.0 Off |                    0 |
# |  0%   32C    P0              69W / 300W |  26206MiB / 46068MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import json
binary_data = r.content

# %%
decoded_data = binary_data.decode('utf-8')
normal_dict = json.loads(decoded_data)

# %%
decoded_data
# Out:
# '{"detail":[{"loc":["body","context"],"msg":"field required","type":"value_error.missing"},{"loc":["body","question"],"msg":"field required","type":"value_error.missing"}]}'

# %%
normal_dict
# Out:
# {'detail': [{'loc': ['body', 'context'],
#    'msg': 'field required',
#    'type': 'value_error.missing'},
#   {'loc': ['body', 'question'],
#    'msg': 'field required',
#    'type': 'value_error.missing'}]}

# %% [markdown]
# # Retriever

# %%
# %%time
r2 = requests.post(
    url='http://127.0.0.1:8001',
    json = {
        "user_input": "在哪里可以设定机种?",
    }
    )
# Out:
# CPU times: user 6.75 ms, sys: 3.02 ms, total: 9.77 ms
# Wall time: 8.68 s

# %%
json.loads(r2.content.decode('utf-8'))
# Out:
# {'user_input': '在哪里可以设定机种?',
#  'relavant_docs': [{'page_content': '选择是否设定附加规则 , 限制 SN长度或厂家代码范围等 , 设定完毕后 , 点击【保存】 , \n完成该产品序列号判定逻辑设定 .',
#    'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf',
#    'page': 7},
#   {'page_content': '选定不良代码 , 点击进入客户绑定页面 ; 勾选客户 , 点击【保存】完成不良判定代码\n与客户的绑定 ; \n \n \n保修设定  \n1. 定义产品 (整机料号信息 ) \n单笔或批量将产品信息导入系统 ,包含机种、厂家料号、客户料号、供应商料号、替代\n料号等信息  \n1.1 机种管理  \n若产品涉及机种 , 需先将机种信息新增至系统 , 以便后续选择 . \na. 单笔新增机种  \n厂家保修管理 后台 ->保修设定 ->定义产品 , 点击【机种管理】按钮 , 点击【新增】填写\n机种名称 , 点击【保存】完成 ;',
#    'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf',
#    'page': 10},
# ...

# %%
import requests

# %%
# %%time
r1 = requests.post(
    url='http://127.0.0.1:8006/get_relevant_docs',
    json = {
        "user_input": "How can I navigate to the RMA request page in the Wareconn Customer Portal?",
        "k": 1,
        "lang": "en_us",
    }
    )
# r = requests.get('http://127.0.0.1:8000')

# print(r.content)
# Out:
# CPU times: user 4.94 ms, sys: 2.92 ms, total: 7.86 ms
# Wall time: 1.43 s

# %%
json.loads(r1.content.decode('utf-8'))
# Out:
# {'relavant_docs': [{'page_content': '2 / 6 \nThis document  belongs to Wareconn  Technology Services (Tianjin) Co., Ltd. It is only intended to be \nused to introduce Wareconn functions and procedures. Please do not use it for other purposes.  2 wareconn standard operating procedure  \nSOP  \nI. This guide will walk you through the process of requesting  RMA  through the \nWareconn Customer Portal.  \nII. Details on how to fill in the Part Number (PN) and Serial Number (SN)  \n1.1 RMA request  procedure (Parts return)  \n1. System login  \n⚫ Module: https://www.wareconn.com/  \n⚫ Description:  Login  with account and password  \n \nTo log in, follow these steps:  \nGo to https://www.wareconn.com/ and click Log in  \n \nFill in your email and password, then click Login\n \nClick Enter  in the Customer portal',
#    'source': 'MSFT RMA request SOP v1.0.pdf',
#    'page': 1},
# ...

# %%
# %%time
r1 = requests.post(
    url='http://127.0.0.1:8006/get_relevant_docs',
    json = {
        "user_input": "自动核准后还需要进行单号提交吗?",
        "k": 1,
        "lang": "zh_tw",
    }
    )
# r = requests.get('http://127.0.0.1:8000')

# print(r.content)
# Out:
# CPU times: user 6.55 ms, sys: 2.04 ms, total: 8.59 ms
# Wall time: 43.3 ms

# %%
json.loads(r1.content.decode('utf-8'))
# Out:
# {'relavant_docs': [{'page_content': '2. 单号分配  \n厂家保修管理 后台->保修作业 ->单号分配 , 勾选送修项目 , 点击【分配 Ware no. 】分\n配单号,同客户同申请人的送修清单 , 可一次分配 Ware no.;  \n \n勾选送修项目 , 点击【指派 Ware no.】, 系统根据产品型号、退运原因、维修地址、服\n务类型等对产品分类并分配  Ware no.;  \n备注 : 若客户需使用自主 RMA no.，亦可在【自定单号】添加客户指定 RMA no.',
#    'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf',
#    'page': 21}]}

# %%
import requests

# %% [markdown]
# # Embedding

# %%
# %%time
r = requests.post(
    url='http://127.0.0.1:8006/embeddings',
    json = {
        "input": [
            "自动核准后还需要进行单号提交吗?",
            "在哪里可以设定机种?"
        ],
        "lang": "zh_tw",
    }
    )
# Out:
# CPU times: user 6.34 ms, sys: 2.14 ms, total: 8.48 ms
# Wall time: 51.3 ms

# %%
import json
binary_data = r.content
decoded_data = binary_data.decode('utf-8')
normal_dict = json.loads(decoded_data)

# %%
normal_dict
# Out:
# {'data': [{'embedding': [-0.20340260863304138,
#     0.1684746891260147,
#     0.00971008837223053,
#     -0.6721699237823486,
#     0.5948507785797119,
#     0.44949638843536377,
#     -1.5037503242492676,
#     -0.3645186424255371,
#     0.8907342553138733,
#     -0.2652752697467804,
#     0.33431434631347656,
#     0.41838642954826355,
#     1.7218856811523438,
#     -0.3007124364376068,
#     -0.6944087743759155,
#     -1.012887954711914,
#     -1.1274762153625488,
#     0.8649397492408752,
#     2.4755759239196777,
#     0.1702537089586258,
#     0.1501266062259674,
#     0.06269367784261703,
#     0.890800952911377,
#     -0.03889414668083191,
#     -0.42087313532829285,
#     -0.3746609687805176,
#     0.4931648373603821,
#     1.9052618741989136,
#     0.0141221284866333,
#     1.7093307971954346,
#     0.3229580521583557,
#     0.0320172943174839,
#     -0.27543970942497253,
#     -1.2658991813659668,
#     1.097551703453064,
#     -0.2828260660171509,
# ...

# %% [markdown]
# # LLM

# %%
out2 = json.loads(r2.content.decode('utf-8'))

# %%
out2["relavant_docs"]
# Out:
# [{'page_content': '选择是否设定附加规则 , 限制 SN长度或厂家代码范围等 , 设定完毕后 , 点击【保存】 , \n完成该产品序列号判定逻辑设定 .',
#   'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf',
#   'page': 7},
#  {'page_content': '选定不良代码 , 点击进入客户绑定页面 ; 勾选客户 , 点击【保存】完成不良判定代码\n与客户的绑定 ; \n \n \n保修设定  \n1. 定义产品 (整机料号信息 ) \n单笔或批量将产品信息导入系统 ,包含机种、厂家料号、客户料号、供应商料号、替代\n料号等信息  \n1.1 机种管理  \n若产品涉及机种 , 需先将机种信息新增至系统 , 以便后续选择 . \na. 单笔新增机种  \n厂家保修管理 后台 ->保修设定 ->定义产品 , 点击【机种管理】按钮 , 点击【新增】填写\n机种名称 , 点击【保存】完成 ;',
#   'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf',
#   'page': 10},
# ...

# %%
content2 = " ".join([cur["page_content"] for cur in out2["relavant_docs"]])

# %%
content2
# Out:
# '选择是否设定附加规则 , 限制 SN长度或厂家代码范围等 , 设定完毕后 , 点击【保存】 , \n完成该产品序列号判定逻辑设定 . 选定不良代码 , 点击进入客户绑定页面 ; 勾选客户 , 点击【保存】完成不良判定代码\n与客户的绑定 ; \n \n \n保修设定  \n1. 定义产品 (整机料号信息 ) \n单笔或批量将产品信息导入系统 ,包含机种、厂家料号、客户料号、供应商料号、替代\n料号等信息  \n1.1 机种管理  \n若产品涉及机种 , 需先将机种信息新增至系统 , 以便后续选择 . \na. 单笔新增机种  \n厂家保修管理 后台 ->保修设定 ->定义产品 , 点击【机种管理】按钮 , 点击【新增】填写\n机种名称 , 点击【保存】完成 ; 1.9 产品与附件绑定  \n本操作步骤 , 需要在本章 2. 定义附件  操作完成后进行 . \n厂家保修管理 后台 ->保修设定 ->定义产品 , 选定产品 , 点击按钮 , 点击【绑定附件】并勾\n选对应附 件、填写数量 , 点击【绑定】完成 ; \n \n \n2. 定义部件 （备品料号信息）  \n若部件中涉及机种管理 , 亦需先新增或上传机种 , 而后操作步骤同定义产品  \n2.1 新增部件机种  \n点击【机种管理】按钮 , 点击【新增】单笔新增机种 ; 点击【上传机种】下载模板 , 批\n量新增机种 ;  \n2.2 新增部件  \n点击【新增部件】单笔新增部件 ; 点击【上传部件】下拉框 , 下载模板批量新增部件 ; \n2.3 新增部件客户料号 ; \n点击【料号对照】添加客户料号 , 选定产品 , 点击单笔添加 ; 点击【料号对照】下载模\n板, 批量上传料号 ; \n2.3 新增供应商料号  \n点击【供应商料号】 , 选定产品 , 点击按钮 , 点击【添加供应商】 , 添加供应商及供应\n商料号 , 【保存】完成 .'

# %%
# %%time
r2_llm = requests.post(
    url='http://127.0.0.1:8000/completion',
    json = {
        "context": content2,
        "question": out2["user_input"]
    }
    )
# Out:
# CPU times: user 5.11 ms, sys: 3.12 ms, total: 8.23 ms
# Wall time: 2.5 s

# %%
r2_llm
# Out:
# <Response [200]>

# %%
r2_llm_out = json.loads(r2_llm.content.decode('utf-8'))

# %%
r2_llm_out
# Out:
# {'completion': ' 在厂家保修管理 后台 -> 保修设定 -> 定义产品 -> 机种管理 -> 单笔新增机种 中进行设定。\n'}

# %%
# %%time
r2_llm = requests.post(
    url='http://127.0.0.1:8000/completion',
    json = {
        "context": content2,
        "question": out2["user_input"],
        "temperature": 1
    }
    )
# Out:
# CPU times: user 7.04 ms, sys: 988 µs, total: 8.03 ms
# Wall time: 1.78 s

# %%
r2_llm_out = json.loads(r2_llm.content.decode('utf-8'))

# %%
r2_llm_out
# Out:
# {'completion': ' 在厂家保修管理 后台 -> 保修设定 -> 定义产品 -> 机种管理 -> 单笔新增机种。\n'}

# %%
# %%time
r2_llm = requests.post(
    url='http://127.0.0.1:8006/question_answering',
    json = {
        "context": "我從事軟體工程業",
        "question": "我從事甚麼行業?",
        "lang": "zh_tw",
        # "temperature": 1
    }
    )
# Out:
# CPU times: user 4.87 ms, sys: 3.13 ms, total: 8 ms
# Wall time: 6.72 ms

# %%
r2_llm.content
# Out:
# b'{"detail":"Not Found"}'

# %%
r2_llm_out = json.loads(r2_llm.content.decode('utf-8'))

# %%
r2_llm_out
# Out:
# {'detail': 'Not Found'}

# %%
context="""
  2 / 6
This document  belongs to Wareconn  Technology Services (Tianjin) Co., Ltd. It is only intended to be
used to introduce Wareconn functions and procedures. Please do not use it for other purposes.  2 wareconn standard operating procedure
SOP
I. This guide will walk you through the process of requesting  RMA  through the
Wareconn Customer Portal.
II. Details on how to fill in the Part Number (PN) and Serial Number (SN)
1.1 RMA request  procedure (Parts return)
1. System login
⚫ Module: https://www.wareconn.com/
⚫ Description:  Login  with account and password

To log in, follow these steps:
Go to https://www.wareconn.com/ and click Log in

Fill in your email and password, then click Login

Click Enter  in the Customer portal3 / 6
This document  belongs to Wareconn  Technology Services (Tianjin) Co., Ltd. It is only intended to be
used to introduce Wareconn functions and procedures. Please do not use it for other purposes.  3 wareconn standard operating procedure
2. Go to  RMA Request  Page
⚫ Module: Customer portal -Warranty Claims -Warranty Claims
⚫ Description: Go to RMA request page

To go to the RMA request page, follow these steps:
Click Warranty Claims  in the left menu, then click +Add

Click the icon shown in the image below
(Select the corresponding SI )4 / 6
This document  belongs to Wareconn  Technology Services (Tianjin) Co., Ltd. It is only intended to be
used to introduce Wareconn functions and procedures. Please do not use it for other purposes.  4 wareconn standard operating procedure
3. Create RMA Request
⚫ Module: Customer portal -Warranty Claims -Warranty Claims -Create request
⚫ Description: Create RMA request order

To create a RMA request, follow these steps:
Click Add Warranty Claims

Then, click Parts Return"""

# %%
q1="How can I navigate to the RMA request page in the Wareconn Customer Portal?"

# %%
# %%time
r2_llm_en = requests.post(
    url='http://127.0.0.1:8001/question_answering',
    json = {
        "context": context,
        "question": q1,
        "lang": "en_us",
        "temperature": 0.2
    }
    )
# Out:
# CPU times: user 9.21 ms, sys: 0 ns, total: 9.21 ms
# Wall time: 17.2 s

# %%
r2_llm_out = json.loads(r2_llm_en.content.decode('utf-8'))

# %%
r2_llm_out
# Out:
# {'completion': ' You can navigate to the RMA request page in the Wareconn Customer Portal by following these steps:\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\
# ...

# %%
import requests
import json

# %%
question1 = "How can I navigate to the RMA request page in the Wareconn Customer Portal?"

# %%
# %%time
r2_llm_en = requests.post(
    url='http://127.0.0.1:8006/question_answering',
    json = {
        "question": question1,
        "lang": "en_us",
    }
    )
# Out:
# CPU times: user 6.78 ms, sys: 1.58 ms, total: 8.36 ms
# Wall time: 2.6 s

# %%
json.loads(r2_llm_en.content.decode('utf-8'))
# Out:
# {'query': 'How can I navigate to the RMA request page in the Wareconn Customer Portal?',
#  'result': ' You can navigate to the RMA request page by following the steps outlined in the document. First, log in to the Wareconn Customer Portal using your email and password. Once logged in, click on the Warranty Claims module in the left menu, then click +Add. Finally, click on the Create Request button to access the RMA request page.',
# ...

# %%
# %%time
r_embed = requests.post(
    url='http://127.0.0.1:8006/embeddings',
    json = {
        "input": [
            "How can I navigate to the RMA request page in the Wareconn Customer Portal?",
            "What does the Reminder field indicate when submitting an RMA request?"
        ],
        "lang": "en_us",
    }
    )
# Out:
# CPU times: user 7.16 ms, sys: 1.2 ms, total: 8.35 ms
# Wall time: 50.7 ms

# %%
r_embed
# Out:
# <Response [200]>

# %%
json.loads(r_embed.content.decode('utf-8'))
# Out:
# {'data': [{'embedding': [-0.01132982037961483,
#     0.05407415330410004,
#     0.014906986616551876,
#     -0.047731731086969376,
#     -0.03518570959568024,
#     -0.056713927537202835,
#     -0.02977672778069973,
#     0.07238280028104782,
#     -0.006995447911322117,
#     -0.02074417471885681,
#     0.013528759591281414,
#     -0.02040492556989193,
#     -0.014329630881547928,
#     -0.09724839776754379,
#     -0.039499681442976,
#     -0.03887033835053444,
#     0.027153611183166504,
#     -0.01672426611185074,
#     -0.0031158574856817722,
#     0.021143388003110886,
#     -0.02007231116294861,
#     -0.018479883670806885,
#     -0.040521323680877686,
#     0.0015740718226879835,
#     -0.005339865572750568,
#     -0.05561864376068115,
#     0.04995877295732498,
#     0.002666015410795808,
#     -0.020936081185936928,
#     0.018676280975341797,
#     0.04689091816544533,
#     0.04374333843588829,
#     0.004731824621558189,
#     -0.03168858587741852,
# ...

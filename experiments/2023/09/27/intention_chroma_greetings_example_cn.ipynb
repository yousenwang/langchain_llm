# %%
# !nvidia-smi
# Out:
# Wed Sep 27 09:10:26 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A40                     Off | 00000000:AF:00.0 Off |                    0 |
# |  0%   30C    P0              69W / 300W |  15303MiB / 46068MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A    105327      C   /data/python/laby/llama.cpp/server         6700MiB |
# |    0   N/A  N/A    105348      C   ...ython/laby/text2vec/env/bin/python3      978MiB |
# |    0   N/A  N/A    105351      C   /data/python/laby/llama.cpp/server         7592MiB |
# +---------------------------------------------------------------------------------------+

# %%
from langchain.vectorstores import Chroma
from langchain.docstore.document import Document

# %%
from langchain.embeddings import HuggingFaceInstructEmbeddings

instructor_embeddings = HuggingFaceInstructEmbeddings(model_name="/root/.cache/torch/sentence_transformers/GanymedeNil_text2vec-large-chinese",
                                                      # local_files_only=True,
                                                      model_kwargs={"device": "cuda"})
# Out:
# /usr/local/lib/python3.10/site-packages/InstructorEmbedding/instructor.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import trange
# No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/GanymedeNil_text2vec-large-chinese. Creating a new one with MEAN pooling.
# 2023-09-27 11:42:48.573891: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-27 11:42:49.339522: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
persist_directory = 'db_cn'

vectordb = Chroma(persist_directory=persist_directory,
                  embedding_function=instructor_embeddings,
                  collection_metadata={"hnsw:space": "cosine"} # l2
                 )

# https://api.python.langchain.com/en/latest/_modules/langchain/vectorstores/chroma.html#Chroma.similarity_search_with_score

# %%
greetings = {
    "category": "greetings",
    "greetings": [
        "你好吗?",
        "一切都好嗎?",
        "很高興認識你",
        "早上好"
    ]
}

# %%
greeting_docs = list(map(lambda x: Document(page_content=x, metadata={"category": greetings["category"]}), greetings["greetings"]))

# %%
greeting_docs[0]
# Out:
# Document(page_content='你好吗?', metadata={'category': 'greetings'})

# %%
vectordb._collection.count()
# Out:
# 31

# %%
new_ids = [greetings["category"]+"_"+str(i) for i in range(len(greeting_docs))]

# %%
new_ids
# Out:
# ['greetings_0', 'greetings_1', 'greetings_2', 'greetings_3']

# %%
return_ids = vectordb.add_documents(
    greeting_docs,
    ids=new_ids
)

# %%
vectordb._collection.count()
# Out:
# 31

# %%
vectordb.persist()

# %%
vectordb._collection.get(ids=["greetings_0","greetings_1"])
# Out:
# {'ids': ['greetings_0', 'greetings_1'],
#  'embeddings': None,
#  'documents': ['你好吗?', '一切都好嗎?'],
#  'metadatas': [{'category': 'greetings'}, {'category': 'greetings'}]}

# %%
vectordb.get(
    where={"category": greetings["category"]}
)
# Out:
# {'ids': ['greetings_0', 'greetings_1', 'greetings_2', 'greetings_3'],
#  'embeddings': None,
#  'documents': ['你好吗?', '一切都好嗎?', '很高興認識你', '早上好'],
#  'metadatas': [{'category': 'greetings'},
#   {'category': 'greetings'},
#   {'category': 'greetings'},
#   {'category': 'greetings'}]}

# %% [markdown]
# ### Cosine distance the lower the better [0,1]

# %% [markdown]
# ### 相似問候語

# %%
# 相似問候語 l2
vectordb.similarity_search_with_score("你過得如何呀?", k = 3)
# Out:
# [(Document(page_content='你好吗?', metadata={'category': 'greetings'}),
#   330.80352783203125),
#  (Document(page_content='很高興認識你', metadata={'category': 'greetings'}),
#   427.43768310546875),
#  (Document(page_content='一切都好嗎?', metadata={'category': 'greetings'}),
#   434.787841796875)]

# %%
# 相似問候語
vectordb.similarity_search_with_score("你過得如何呀?", k = 3)
# Out:
# [(Document(page_content='你好吗?', metadata={'category': 'greetings'}),
#   -17.13308334350586),
#  (Document(page_content='很高興認識你', metadata={'category': 'greetings'}),
#   -15.54990005493164),
#  (Document(page_content='一切都好嗎?', metadata={'category': 'greetings'}),
#   -14.909040451049805)]

# %%
embed = instructor_embeddings.client.encode("你過得如何呀?")
print(embed)
# Out:
# [ 1.0175216  -0.31168896 -1.0131493  ...  1.0608912   0.0557702
#  -0.25220978]

# %%
# 相似問候語
vectordb.similarity_search_by_vector_with_relevance_scores(embed.tolist(), k = 3)
# Out:
# [(Document(page_content='你好吗?', metadata={'category': 'greetings'}),
#   -9.387154579162598),
#  (Document(page_content='很高興認識你', metadata={'category': 'greetings'}),
#   -8.423574447631836),
#  (Document(page_content='一切都好嗎?', metadata={'category': 'greetings'}),
#   -7.270807266235352)]

# %% [markdown]
# ### 非數據庫問候語

# %%
# 非數據庫問候語
vectordb.similarity_search_with_score("晚安!", k = 3)
# Out:
# [(Document(page_content='早上好', metadata={'category': 'greetings'}),
#   -15.772579193115234),
#  (Document(page_content='很高興認識你', metadata={'category': 'greetings'}),
#   -14.076789855957031),
#  (Document(page_content='你好吗?', metadata={'category': 'greetings'}),
#   -14.006009101867676)]

# %% [markdown]
# ### 非問候語

# %%
# 非問候語
vectordb.similarity_search_with_score("自动核准后还需要进行单号提交吗?", k = vectordb._collection.count())
# Out:
# [(Document(page_content='2. 单号分配  \n厂家保修管理 后台->保修作业 ->单号分配 , 勾选送修项目 , 点击【分配 Ware no. 】分\n配单号,同客户同申请人的送修清单 , 可一次分配 Ware no.;  \n \n勾选送修项目 , 点击【指派 Ware no.】, 系统根据产品型号、退运原因、维修地址、服\n务类型等对产品分类并分配  Ware no.;  \n备注 : 若客户需使用自主 RMA no.，亦可在【自定单号】添加客户指定 RMA no.', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 21}),
#   -14.272348403930664),
#  (Document(page_content='选定不良代码 , 点击进入客户绑定页面 ; 勾选客户 , 点击【保存】完成不良判定代码\n与客户的绑定 ; \n \n \n保修设定  \n1. 定义产品 (整机料号信息 ) \n单笔或批量将产品信息导入系统 ,包含机种、厂家料号、客户料号、供应商料号、替代\n料号等信息  \n1.1 机种管理  \n若产品涉及机种 , 需先将机种信息新增至系统 , 以便后续选择 . \na. 单笔新增机种  \n厂家保修管理 后台 ->保修设定 ->定义产品 , 点击【机种管理】按钮 , 点击【新增】填写\n机种名称 , 点击【保存】完成 ;', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 10}),
#   -13.937506675720215),
#  (Document(page_content='1.4 添加客户料号  \n点击【批量绑定附件】下拉框 , 选择【下载模板】 , 填写产品料号及所绑附件的名称和数\n量, 点击【批量上传】添加所编辑档案 , 可完成附件的新增和绑定 . \n \n \n1.5 添加客户料号  \n若厂家PN与客户料号不同 , 为方便客户和厂家识别产品 , 可添加客户料号 , 系统自动\n进行转换 ;  \na. 单笔添加客户料号  \n厂家保修管理 后台->保修设定 ->定义产品 , 点击【料号对照 】按钮; 选定产品 , 点击\n填写对应客户的客户料号 , 点击【保存】完成 .', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 13}),
#   -13.924459457397461),
#  (Document(page_content='3. 单号提交  \n厂家保修管理 后台->保修作业 ->单号提交 , 点击按钮, 勾选对应栏位 , 点击【确定】\n可移动或合并 Ware no.分组(同客户同申请人可移动至同一组内 ); 点击提交单号 , \nware no.即生成. \n \n4. 进度追踪  \n4.1 查看保修进度  \n厂家保修管理 后台->保修作业 ->进度追踪 , 点击【保修单号】 , 点击进入送修信息 ; 可\n查看保修及物流进度 ; 【查看报告】 查看服务中心的维修报告 ; 点击可查看该笔 SN的\n产品详情、保修详情、物流资讯和服务进度 .', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 22}),
#   -13.922216415405273),
#  (Document(page_content='点击【编辑替代料号】进入料号管理页面 , 点击【新增替代料号】 , 勾选产品料号, 完\n成替代料号添加 ; 【more】查看已设替代料号 . \n \n \n1.8 产品与部件绑定  \n本操作步骤 , 需要在本章 2. 定义部件  操作完成后进行 . \n厂家保修管理 后台 ->保修设定 ->定义产品 , 选定产品 , 点击按钮 , 点击【绑定部件】并勾\n选对应部件、填写数量 , 点击【绑定】完成 ;', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 15}),
#   -13.862312316894531),
#  (Document(page_content='选择是否设定附加规则 , 限制 SN长度或厂家代码范围等 , 设定完毕后 , 点击【保存】 , \n完成该产品序列号判定逻辑设定 .', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 7}),
#   -13.734223365783691),
#  (Document(page_content='点击【添加代码】 , 选择原因类别 , 编辑原因代码及保修原因 , 选填解决办法 , 勾选\n适用客户 , 点击【保存】完成保修代码设定  \n \n5. 定义附件  \n单笔或批量将 附件信息导入系统 . \n厂家保修管理后台 ->保修设定 ->定义附件 , 点击【新增附件】输入附件名称及备注 , 完\n成单笔新增附件 ;', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 19}),
#   -13.503936767578125),
#  (Document(page_content='一切都好嗎?', metadata={'category': 'greetings'}),
#   -13.461954116821289),
#  (Document(page_content='3. 客户清单  \n厂家保修管理后台 ->客户管理 ->客户清单 , 显示厂家的不同客户清单 , 可针对不同客户\n分别进行不同条件设定 ; 选定客户 , 点击可针对当前客户进行设定  \n- 自动核准 : 勾选后 , 系统自动依厂家的保修设定 , 审核客户保修申请并分配 Ware no.  \n- 验证 SN出货数据 : 在量产出货数据导入 wareconn 系统的前提下 , 可进行勾选；勾选\n后系统自动对客户送修产品 PPID/SN进行鉴权 , 并以出厂日期作为保修起点日期  \n- 自动分配 : 若为手动核准保修申请 , 勾选后 , 系统自动分配 wareno.  \n- 自动发货给消费者 : 针对不同客户发货操作 . 开启此权限 , 申请核准后 , 系统自动发\n货, 发货人为客户申请所填消费者信息 , 并向消费者寄送物流列印标签邮件  \n- 保修申请起点日期设定 : 针对不同客户，配置保修申请起点日期的权限。  开启此权\n限，客户保修申请时，保修起点日期为必填选项  \n- 出货代填 : 勾选后 , 厂家可代替客户填写不良品发货相 关信息', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 5}),
#   -13.262965202331543),
#  (Document(page_content='你好吗?', metadata={'category': 'greetings'}),
#   -13.154373168945312),
#  (Document(page_content='点击【上传附件】下拉框 , 选择【下载模板】填写附件相关信息 , 【批量上传】将编辑好\n的文档上传 , 完成批量新增附件 . \n \n保修作业  \n1. 保修申请 （手动核准） \n若厂家在客户清单中 , 对应客户已设置【自动核准】功能 ; 客户进行保修申请后 , 平台\n依保修条件进行自动核准并分配 ware no.; 若未设定自动核准 , 即可通过手动核准进行\n作业 ; 手动核准作业如下 : \n客户进行保修申请后 , 厂家后台保修申请方有数据 ; \n厂家保修管理 后台 ->保修作业 ->保修申请 , 选择对应送修项目 , 点击按钮进入送修信息 ; \n \n点击可查看客户信息 , 点击【接受】进行核准 , 点击【拒绝】进行驳回 ， 需填写拒绝\n原因; 当客户送修系统判定不可接受时 (即不符合厂家保修设定 ), 点击可变更核准状\n态, 选择保修设定后接受或者拒绝 ;', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 20}),
#   -13.057530403137207),
#  (Document(page_content='b. 批量添加客户料号  \n点击 【料号对照】 下拉框 , 选择 【下载模板】 填写厂家 PN、 客户料号 , 点击 【批量上传】\n选择客户名称、添加编辑后的模板文件 , 点击【保存】完成 ; \n备注: 同客户料号可批量上传  \n \n \n1.6 添加供应商料号  \n若送修过程中涉及供应商料号 , 可点击【供应商料号】 按钮, 选定产品 , 点击按钮,点\n击【添加供应商】填写 供应商及其对应料号 ; \n \n \n \n1.7 添加替代料号  \n若产品涉及替代料号 , 可在新增产品页面设置替代料号 , 但被设置之替代料号需提前\n在系统中 定义完成 , 方可选择设置.', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 14}),
#   -12.888643264770508),
#  (Document(page_content='基本资料  \n1. 角色管理  \n厂家保修管理 后台->基本资料 ->角色管理 , 点击【新增角色】 , 添加角色名称及名称\n描述，勾选角色对应权限 , 点击【保存】按钮 ; \n \n \n2. 账号管理  \n2.1 新增账号  \n厂家保修管理 后台->基本资料 ->账号管理 , 点击【添加账号】按钮 , 填写账号信息 , \n点击【确定】按钮 , 新增账号完成 ;', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 2}),
#   -12.710676193237305),
#  (Document(page_content='2.2 账号权限分配  \n选定账号 , 点击按钮, 可编辑账号 权限, 默认为角色对应权限 .', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 3}),
#   -12.682791709899902),
#  (Document(page_content='1.9 产品与附件绑定  \n本操作步骤 , 需要在本章 2. 定义附件  操作完成后进行 . \n厂家保修管理 后台 ->保修设定 ->定义产品 , 选定产品 , 点击按钮 , 点击【绑定附件】并勾\n选对应附 件、填写数量 , 点击【绑定】完成 ; \n \n \n2. 定义部件 （备品料号信息）  \n若部件中涉及机种管理 , 亦需先新增或上传机种 , 而后操作步骤同定义产品  \n2.1 新增部件机种  \n点击【机种管理】按钮 , 点击【新增】单笔新增机种 ; 点击【上传机种】下载模板 , 批\n量新增机种 ;  \n2.2 新增部件  \n点击【新增部件】单笔新增部件 ; 点击【上传部件】下拉框 , 下载模板批量新增部件 ; \n2.3 新增部件客户料号 ; \n点击【料号对照】添加客户料号 , 选定产品 , 点击单笔添加 ; 点击【料号对照】下载模\n板, 批量上传料号 ; \n2.3 新增供应商料号  \n点击【供应商料号】 , 选定产品 , 点击按钮 , 点击【添加供应商】 , 添加供应商及供应\n商料号 , 【保存】完成 .', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 16}),
#   -12.589277267456055),
#  (Document(page_content='早上好', metadata={'category': 'greetings'}),
#   -12.547380447387695),
#  (Document(page_content='b. 批量新增机种  \n点击【机种管理】按钮 , 点击【上传机种】下拉框 , 选择【下载模板】填写机种名称 , \n点击【上传文件】添加编辑完成的机种资料 , 点击【上传】完成 ; \n \n \n1.2 新增产品  \na. 单笔新增产品  \n厂家保修管理 后台->保修设定 ->定义产品 , 点击【新增产品】按钮 ; 若下拉框中无对\n应产品品牌 , 可点击【添加品牌】新增 ; 若下拉框中无对应产品类别 , 可点击【添加\n类别】新增 , 填写产品信息, 其中*为必填项 , 点击【保存】完成 ;', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 11}),
#   -12.321340560913086),
#  (Document(page_content='2.2 检验逻辑设定   \n逻辑判定设置完成后 , 厂家保修管理 后台->基础设定 ->判定逻辑 , 点击进入逻辑判定\n页面, 最下方输入 PPID, 点击【解析】检验逻辑设定 ;如下图, 可依规则自动解析出厂\n时间等信息 . \n \n3. 保修类别  \n厂家保修管理 后台->基础设定 ->保修类别，点击【新增设定】 , 设定需要为产品配置\n的保修类别 ,填写服务类型、时效值及单位 , 点击【保存】完成 ; \n \n \n4. 保修约定  \n当产品保修及保修卡无法满足保修需求时 , 可添加保修约定 .', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 8}),
#   -12.222784042358398),
#  (Document(page_content='厂家保修管理 后台->基础设定 ->保修约定 , 点击【添加保修约定】 , 填写保修约定名\n称和说明 ; \n保修约定设定完成后 , 选定约定 , 点击【对应客户】 , 设定该约定指定客户 . \n \n \n5. 保修判定  \n提前设置不同的、判定代码，服务中心进度维护时 , 可选择厂家设置的不良判定代\n码，记录不良判定结果，确定责任归属 ; \n厂家保修管理 后台->基础设定 ->保修判定 ,点击【新增判定代码】填写不良代码 名称、\n内容、勾选对应产品 , 点击【保存】完成 ; 点击对不良代码的内容及对应产品进行编\n辑;', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 9}),
#   -11.870092391967773),
#  (Document(page_content='b. 批量新增产品  \n点击【上传产品】下拉框 , 选择【下载模板】填写产品名称、 PN信息, 点击【批量上\n传】填写产品信息、添加编辑后的模板资料 ,  点击【上传】完成 ; \n备注: 批量上传为同品牌、同类别、同机种、同解析逻辑可以一次上传  \n \n \n1.3 批量新增及绑定  \n点击【批量新增及绑定 】下拉框, 选择【下载模板】填写产品相关信息及所绑定部件相\n关信息, 点击【批量上传】添加编辑完成的产品及部件资料 , 点击【上传】完成产品信\n息的添加和部件的添加及绑定 . \n绑定SN的解析规则 , 可用于鉴权和保修期点日期判断', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 12}),
#   -11.742904663085938),
#  (Document(page_content='3. 产品保修 （维修服务 , “退运流程”设置完成后设置）  \n厂家后台 ->保修设定 ->产品保修 , 选定对应客户 , 点击按钮进入页面 ; 点击【新增】设\n置产品保修 ; \n \n \n点击【选择类别】 , 选择维修 /翻新保修约定 , 选择预设置产品所对应的产品类别 , 选\n择保修期间服务内容、具体服务流程、保修期间时长等信息 , 填写完成点击【下一\n步】; \n备注: 保修期间服务内容 , 为上章基础设定中 【保修类别】中设定之 信息; 【服务流\n程】为送修至服务中心 , 本次需选择；  【服务地址 】为送修至厂家 , 不经服务中心 , \n本次不选择 ; \n \n添加产品 PN, 点击【批量添加 PN】， 带出相同类别 PN产品, 勾选后确认 , 即完成产\n品保修设定', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 17}),
#   -11.742348670959473),
#  (Document(page_content='客户管理  \n1. 邀请客户  \n厂家保修管理 后台->客户管理->邀请客户 , 若客户未注册 wareconn保修云平台, 点击\n【邀请客户注册】 按钮, 填写邀请信息, 点击【发送邮件】 , 发送注册邀请 . \n \n \n2. 关联客户  \n厂家保修管理 后台->客户管理->关联申请 , 点击【我发出的关联申请】查看发出的关\n联申请记录；点击【新增关联申请】 , 输入客户信息搜索客户 (已注册),点击申请关\n联;', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 4}),
#   -11.732404708862305),
#  (Document(page_content='基础设定  \n1. 判定命名  \n厂家保修管理 后台->基础设定 ->判定命名 ,依用户习惯 , 自主设定相关栏位名称 , 设定\n后, 系统相关栏位均以设定名称显示 . \n \n2. 判定逻辑  \n设定PPID/SN的逻辑规则 , 用于解析保修起点日期等信息 . \n2.1 添加/编辑判定逻辑  \n厂家保修管理 后台->基础设定 ->判定逻辑 , 点击【添加】按钮 , 添加判定逻辑 ;选定判\n定逻辑, 点击对该判定逻辑进行编辑 ; \n \n填写解码规则名称、说明、 SN样例；点击【编辑】按钮 进行应用 ; \n \n填写 PPID/SN子串区段 , 依照子串区段 的代表意义 , 可自定义规则  \n如下图中点击【月份 规则自定义】 ，  进入自定义模块后 , 点击【新增码值】 , 可自定义\n月份解析规则 , 例如 , 可依 PPID/SN规则设定 A代表 10月, B代表 11月份 , C代表 12月\n份; \n【添加一项自定义规则】可添加 PPID/SN子串逻辑自定义规则 .', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 6}),
#   -11.696629524230957),
#  (Document(page_content='很高興認識你', metadata={'category': 'greetings'}),
#   -11.126791000366211),
#  (Document(page_content='4. 保修原因  \n针对客户及产品类别设定退运原因代码 , 供客户保修申请时选择 , 便于客户描述及厂\n家判断原因  \n厂家保修管理 后台->保修设定->保修原因 , 点击【添加】新增 产品类别; 选择类别及\n应用类型 , 点击【+】增加原因类别 , 点击【-】删除原因类别 , 点击【保存】完成 ; \n \n \n选定产品类别 , 点击进入代码清单页面 , 点击【原因类别设定】 , 【添加类别】新增\n原因类别 , 删除原因类别 , 点击【保存】完成 原因类别设定 ;', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 18}),
#   -11.070815086364746),
#  (Document(page_content='4.2 结案  \n若厂家在【维修服务】中设定服务中心代结案 , 则不需此步操作；若未设定 , 当服务中\n心结案后 , 厂家需进行结案  \n勾选需结案项目 , 点击【结案】 ,完成结案 ; 下载结案模板 ,点击【上传结案】可批量结\n案;点击【已结案清单】可查看已结案信息', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 23}),
#   -10.413875579833984),
#  (Document(page_content='1. 保修申请（手动核准）  ................................ ................................ ................................  21 \n2. 单号分配  ................................ ................................ ................................ ........................  22 \n3. 单号提交  ................................ ................................ ................................ ........................  23 \n4. 进度追踪  ................................ ................................ ................................ ........................  23', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 1}),
#   -10.256746292114258),
#  (Document(page_content='5. 保修判定  ................................ ................................ ................................ ........................  10 \n保修设定  ................................ ................................ ................................ ................................ . 11 \n1. 定义产品 (整机料号信息 ) ................................ ................................ ............................  11 \n2. 定义部件（备品料号信息）  ................................ ................................ ........................  17 \n3. 产品保修（维修服务 , “退运流程”设置完成后设置）  ................................ .........  18 \n4. 保修原因  ................................ ................................ ................................ ........................  19 \n保修作业  ................................ ................................ ................................ ................................ . 21 \n1. 保修申请（手动核准）  ................................ ................................ ................................  21', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 1}),
#   -9.75738525390625),
#  (Document(page_content='保修管理 -厂家SOP \n \n \n2022/11/07                                                  WM.1.0     \n 2023/03/17                                                  WM.2.0 \n目录 \n基本资料  ................................ ................................ ................................ ................................ ... 3 \n1. 角色管理  ................................ ................................ ................................ ..........................  3 \n2. 账号管理  ................................ ................................ ................................ ..........................  3 \n客户管理  ................................ ................................ ................................ ................................ ... 5 \n1. 邀请客户  ................................ ................................ ................................ ..........................  5', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 0}),
#   -8.979958534240723),
#  (Document(page_content='3. 保修类别  ................................ ................................ ................................ ..........................  9 \n4. 保修约定  ................................ ................................ ................................ ..........................  9', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 0}),
#   -8.921101570129395),
#  (Document(page_content='1. 邀请客户  ................................ ................................ ................................ ..........................  5 \n2. 关联客户  ................................ ................................ ................................ ..........................  5 \n3. 客户清单  ................................ ................................ ................................ ..........................  6 \n基础设定  ................................ ................................ ................................ ................................ ... 7 \n1. 判定命名  ................................ ................................ ................................ ..........................  7 \n2. 判定逻辑  ................................ ................................ ................................ ..........................  7 \n3. 保修类别  ................................ ................................ ................................ ..........................  9', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 0}),
#   -6.783437252044678)]

# %% [markdown]
# ### 完全相同問候語

# %%
# 完全相同問候語
vectordb.similarity_search_with_score("早上好", k = vectordb._collection.count())
# Out:
# [(Document(page_content='早上好', metadata={'category': 'greetings'}),
#   -20.439983367919922),
#  (Document(page_content='一切都好嗎?', metadata={'category': 'greetings'}),
#   -13.827183723449707),
#  (Document(page_content='你好吗?', metadata={'category': 'greetings'}),
#   -13.778666496276855),
#  (Document(page_content='很高興認識你', metadata={'category': 'greetings'}),
#   -13.566693305969238),
#  (Document(page_content='点击【添加代码】 , 选择原因类别 , 编辑原因代码及保修原因 , 选填解决办法 , 勾选\n适用客户 , 点击【保存】完成保修代码设定  \n \n5. 定义附件  \n单笔或批量将 附件信息导入系统 . \n厂家保修管理后台 ->保修设定 ->定义附件 , 点击【新增附件】输入附件名称及备注 , 完\n成单笔新增附件 ;', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 19}),
#   -11.46774673461914),
#  (Document(page_content='2. 单号分配  \n厂家保修管理 后台->保修作业 ->单号分配 , 勾选送修项目 , 点击【分配 Ware no. 】分\n配单号,同客户同申请人的送修清单 , 可一次分配 Ware no.;  \n \n勾选送修项目 , 点击【指派 Ware no.】, 系统根据产品型号、退运原因、维修地址、服\n务类型等对产品分类并分配  Ware no.;  \n备注 : 若客户需使用自主 RMA no.，亦可在【自定单号】添加客户指定 RMA no.', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 21}),
#   -11.064899444580078),
#  (Document(page_content='点击【编辑替代料号】进入料号管理页面 , 点击【新增替代料号】 , 勾选产品料号, 完\n成替代料号添加 ; 【more】查看已设替代料号 . \n \n \n1.8 产品与部件绑定  \n本操作步骤 , 需要在本章 2. 定义部件  操作完成后进行 . \n厂家保修管理 后台 ->保修设定 ->定义产品 , 选定产品 , 点击按钮 , 点击【绑定部件】并勾\n选对应部件、填写数量 , 点击【绑定】完成 ;', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 15}),
#   -11.002779006958008),
#  (Document(page_content='选择是否设定附加规则 , 限制 SN长度或厂家代码范围等 , 设定完毕后 , 点击【保存】 , \n完成该产品序列号判定逻辑设定 .', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 7}),
#   -10.838571548461914),
#  (Document(page_content='2.2 账号权限分配  \n选定账号 , 点击按钮, 可编辑账号 权限, 默认为角色对应权限 .', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 3}),
#   -10.706217765808105),
#  (Document(page_content='b. 批量新增产品  \n点击【上传产品】下拉框 , 选择【下载模板】填写产品名称、 PN信息, 点击【批量上\n传】填写产品信息、添加编辑后的模板资料 ,  点击【上传】完成 ; \n备注: 批量上传为同品牌、同类别、同机种、同解析逻辑可以一次上传  \n \n \n1.3 批量新增及绑定  \n点击【批量新增及绑定 】下拉框, 选择【下载模板】填写产品相关信息及所绑定部件相\n关信息, 点击【批量上传】添加编辑完成的产品及部件资料 , 点击【上传】完成产品信\n息的添加和部件的添加及绑定 . \n绑定SN的解析规则 , 可用于鉴权和保修期点日期判断', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 12}),
#   -10.570488929748535),
#  (Document(page_content='选定不良代码 , 点击进入客户绑定页面 ; 勾选客户 , 点击【保存】完成不良判定代码\n与客户的绑定 ; \n \n \n保修设定  \n1. 定义产品 (整机料号信息 ) \n单笔或批量将产品信息导入系统 ,包含机种、厂家料号、客户料号、供应商料号、替代\n料号等信息  \n1.1 机种管理  \n若产品涉及机种 , 需先将机种信息新增至系统 , 以便后续选择 . \na. 单笔新增机种  \n厂家保修管理 后台 ->保修设定 ->定义产品 , 点击【机种管理】按钮 , 点击【新增】填写\n机种名称 , 点击【保存】完成 ;', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 10}),
#   -10.562004089355469),
#  (Document(page_content='1.4 添加客户料号  \n点击【批量绑定附件】下拉框 , 选择【下载模板】 , 填写产品料号及所绑附件的名称和数\n量, 点击【批量上传】添加所编辑档案 , 可完成附件的新增和绑定 . \n \n \n1.5 添加客户料号  \n若厂家PN与客户料号不同 , 为方便客户和厂家识别产品 , 可添加客户料号 , 系统自动\n进行转换 ;  \na. 单笔添加客户料号  \n厂家保修管理 后台->保修设定 ->定义产品 , 点击【料号对照 】按钮; 选定产品 , 点击\n填写对应客户的客户料号 , 点击【保存】完成 .', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 13}),
#   -10.542142868041992),
#  (Document(page_content='3. 单号提交  \n厂家保修管理 后台->保修作业 ->单号提交 , 点击按钮, 勾选对应栏位 , 点击【确定】\n可移动或合并 Ware no.分组(同客户同申请人可移动至同一组内 ); 点击提交单号 , \nware no.即生成. \n \n4. 进度追踪  \n4.1 查看保修进度  \n厂家保修管理 后台->保修作业 ->进度追踪 , 点击【保修单号】 , 点击进入送修信息 ; 可\n查看保修及物流进度 ; 【查看报告】 查看服务中心的维修报告 ; 点击可查看该笔 SN的\n产品详情、保修详情、物流资讯和服务进度 .', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 22}),
#   -10.475983619689941),
#  (Document(page_content='1.9 产品与附件绑定  \n本操作步骤 , 需要在本章 2. 定义附件  操作完成后进行 . \n厂家保修管理 后台 ->保修设定 ->定义产品 , 选定产品 , 点击按钮 , 点击【绑定附件】并勾\n选对应附 件、填写数量 , 点击【绑定】完成 ; \n \n \n2. 定义部件 （备品料号信息）  \n若部件中涉及机种管理 , 亦需先新增或上传机种 , 而后操作步骤同定义产品  \n2.1 新增部件机种  \n点击【机种管理】按钮 , 点击【新增】单笔新增机种 ; 点击【上传机种】下载模板 , 批\n量新增机种 ;  \n2.2 新增部件  \n点击【新增部件】单笔新增部件 ; 点击【上传部件】下拉框 , 下载模板批量新增部件 ; \n2.3 新增部件客户料号 ; \n点击【料号对照】添加客户料号 , 选定产品 , 点击单笔添加 ; 点击【料号对照】下载模\n板, 批量上传料号 ; \n2.3 新增供应商料号  \n点击【供应商料号】 , 选定产品 , 点击按钮 , 点击【添加供应商】 , 添加供应商及供应\n商料号 , 【保存】完成 .', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 16}),
#   -10.310665130615234),
#  (Document(page_content='3. 客户清单  \n厂家保修管理后台 ->客户管理 ->客户清单 , 显示厂家的不同客户清单 , 可针对不同客户\n分别进行不同条件设定 ; 选定客户 , 点击可针对当前客户进行设定  \n- 自动核准 : 勾选后 , 系统自动依厂家的保修设定 , 审核客户保修申请并分配 Ware no.  \n- 验证 SN出货数据 : 在量产出货数据导入 wareconn 系统的前提下 , 可进行勾选；勾选\n后系统自动对客户送修产品 PPID/SN进行鉴权 , 并以出厂日期作为保修起点日期  \n- 自动分配 : 若为手动核准保修申请 , 勾选后 , 系统自动分配 wareno.  \n- 自动发货给消费者 : 针对不同客户发货操作 . 开启此权限 , 申请核准后 , 系统自动发\n货, 发货人为客户申请所填消费者信息 , 并向消费者寄送物流列印标签邮件  \n- 保修申请起点日期设定 : 针对不同客户，配置保修申请起点日期的权限。  开启此权\n限，客户保修申请时，保修起点日期为必填选项  \n- 出货代填 : 勾选后 , 厂家可代替客户填写不良品发货相 关信息', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 5}),
#   -10.245445251464844),
#  (Document(page_content='b. 批量添加客户料号  \n点击 【料号对照】 下拉框 , 选择 【下载模板】 填写厂家 PN、 客户料号 , 点击 【批量上传】\n选择客户名称、添加编辑后的模板文件 , 点击【保存】完成 ; \n备注: 同客户料号可批量上传  \n \n \n1.6 添加供应商料号  \n若送修过程中涉及供应商料号 , 可点击【供应商料号】 按钮, 选定产品 , 点击按钮,点\n击【添加供应商】填写 供应商及其对应料号 ; \n \n \n \n1.7 添加替代料号  \n若产品涉及替代料号 , 可在新增产品页面设置替代料号 , 但被设置之替代料号需提前\n在系统中 定义完成 , 方可选择设置.', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 14}),
#   -10.21098518371582),
#  (Document(page_content='基本资料  \n1. 角色管理  \n厂家保修管理 后台->基本资料 ->角色管理 , 点击【新增角色】 , 添加角色名称及名称\n描述，勾选角色对应权限 , 点击【保存】按钮 ; \n \n \n2. 账号管理  \n2.1 新增账号  \n厂家保修管理 后台->基本资料 ->账号管理 , 点击【添加账号】按钮 , 填写账号信息 , \n点击【确定】按钮 , 新增账号完成 ;', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 2}),
#   -10.160867691040039),
#  (Document(page_content='3. 产品保修 （维修服务 , “退运流程”设置完成后设置）  \n厂家后台 ->保修设定 ->产品保修 , 选定对应客户 , 点击按钮进入页面 ; 点击【新增】设\n置产品保修 ; \n \n \n点击【选择类别】 , 选择维修 /翻新保修约定 , 选择预设置产品所对应的产品类别 , 选\n择保修期间服务内容、具体服务流程、保修期间时长等信息 , 填写完成点击【下一\n步】; \n备注: 保修期间服务内容 , 为上章基础设定中 【保修类别】中设定之 信息; 【服务流\n程】为送修至服务中心 , 本次需选择；  【服务地址 】为送修至厂家 , 不经服务中心 , \n本次不选择 ; \n \n添加产品 PN, 点击【批量添加 PN】， 带出相同类别 PN产品, 勾选后确认 , 即完成产\n品保修设定', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 17}),
#   -10.1185941696167),
#  (Document(page_content='2.2 检验逻辑设定   \n逻辑判定设置完成后 , 厂家保修管理 后台->基础设定 ->判定逻辑 , 点击进入逻辑判定\n页面, 最下方输入 PPID, 点击【解析】检验逻辑设定 ;如下图, 可依规则自动解析出厂\n时间等信息 . \n \n3. 保修类别  \n厂家保修管理 后台->基础设定 ->保修类别，点击【新增设定】 , 设定需要为产品配置\n的保修类别 ,填写服务类型、时效值及单位 , 点击【保存】完成 ; \n \n \n4. 保修约定  \n当产品保修及保修卡无法满足保修需求时 , 可添加保修约定 .', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 8}),
#   -10.098289489746094),
#  (Document(page_content='b. 批量新增机种  \n点击【机种管理】按钮 , 点击【上传机种】下拉框 , 选择【下载模板】填写机种名称 , \n点击【上传文件】添加编辑完成的机种资料 , 点击【上传】完成 ; \n \n \n1.2 新增产品  \na. 单笔新增产品  \n厂家保修管理 后台->保修设定 ->定义产品 , 点击【新增产品】按钮 ; 若下拉框中无对\n应产品品牌 , 可点击【添加品牌】新增 ; 若下拉框中无对应产品类别 , 可点击【添加\n类别】新增 , 填写产品信息, 其中*为必填项 , 点击【保存】完成 ;', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 11}),
#   -10.015636444091797),
#  (Document(page_content='客户管理  \n1. 邀请客户  \n厂家保修管理 后台->客户管理->邀请客户 , 若客户未注册 wareconn保修云平台, 点击\n【邀请客户注册】 按钮, 填写邀请信息, 点击【发送邮件】 , 发送注册邀请 . \n \n \n2. 关联客户  \n厂家保修管理 后台->客户管理->关联申请 , 点击【我发出的关联申请】查看发出的关\n联申请记录；点击【新增关联申请】 , 输入客户信息搜索客户 (已注册),点击申请关\n联;', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 4}),
#   -9.595479011535645),
#  (Document(page_content='3. 保修类别  ................................ ................................ ................................ ..........................  9 \n4. 保修约定  ................................ ................................ ................................ ..........................  9', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 0}),
#   -9.44392204284668),
#  (Document(page_content='厂家保修管理 后台->基础设定 ->保修约定 , 点击【添加保修约定】 , 填写保修约定名\n称和说明 ; \n保修约定设定完成后 , 选定约定 , 点击【对应客户】 , 设定该约定指定客户 . \n \n \n5. 保修判定  \n提前设置不同的、判定代码，服务中心进度维护时 , 可选择厂家设置的不良判定代\n码，记录不良判定结果，确定责任归属 ; \n厂家保修管理 后台->基础设定 ->保修判定 ,点击【新增判定代码】填写不良代码 名称、\n内容、勾选对应产品 , 点击【保存】完成 ; 点击对不良代码的内容及对应产品进行编\n辑;', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 9}),
#   -9.35934066772461),
#  (Document(page_content='基础设定  \n1. 判定命名  \n厂家保修管理 后台->基础设定 ->判定命名 ,依用户习惯 , 自主设定相关栏位名称 , 设定\n后, 系统相关栏位均以设定名称显示 . \n \n2. 判定逻辑  \n设定PPID/SN的逻辑规则 , 用于解析保修起点日期等信息 . \n2.1 添加/编辑判定逻辑  \n厂家保修管理 后台->基础设定 ->判定逻辑 , 点击【添加】按钮 , 添加判定逻辑 ;选定判\n定逻辑, 点击对该判定逻辑进行编辑 ; \n \n填写解码规则名称、说明、 SN样例；点击【编辑】按钮 进行应用 ; \n \n填写 PPID/SN子串区段 , 依照子串区段 的代表意义 , 可自定义规则  \n如下图中点击【月份 规则自定义】 ，  进入自定义模块后 , 点击【新增码值】 , 可自定义\n月份解析规则 , 例如 , 可依 PPID/SN规则设定 A代表 10月, B代表 11月份 , C代表 12月\n份; \n【添加一项自定义规则】可添加 PPID/SN子串逻辑自定义规则 .', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 6}),
#   -9.332664489746094),
#  (Document(page_content='点击【上传附件】下拉框 , 选择【下载模板】填写附件相关信息 , 【批量上传】将编辑好\n的文档上传 , 完成批量新增附件 . \n \n保修作业  \n1. 保修申请 （手动核准） \n若厂家在客户清单中 , 对应客户已设置【自动核准】功能 ; 客户进行保修申请后 , 平台\n依保修条件进行自动核准并分配 ware no.; 若未设定自动核准 , 即可通过手动核准进行\n作业 ; 手动核准作业如下 : \n客户进行保修申请后 , 厂家后台保修申请方有数据 ; \n厂家保修管理 后台 ->保修作业 ->保修申请 , 选择对应送修项目 , 点击按钮进入送修信息 ; \n \n点击可查看客户信息 , 点击【接受】进行核准 , 点击【拒绝】进行驳回 ， 需填写拒绝\n原因; 当客户送修系统判定不可接受时 (即不符合厂家保修设定 ), 点击可变更核准状\n态, 选择保修设定后接受或者拒绝 ;', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 20}),
#   -8.98674201965332),
#  (Document(page_content='4. 保修原因  \n针对客户及产品类别设定退运原因代码 , 供客户保修申请时选择 , 便于客户描述及厂\n家判断原因  \n厂家保修管理 后台->保修设定->保修原因 , 点击【添加】新增 产品类别; 选择类别及\n应用类型 , 点击【+】增加原因类别 , 点击【-】删除原因类别 , 点击【保存】完成 ; \n \n \n选定产品类别 , 点击进入代码清单页面 , 点击【原因类别设定】 , 【添加类别】新增\n原因类别 , 删除原因类别 , 点击【保存】完成 原因类别设定 ;', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 18}),
#   -8.530804634094238),
#  (Document(page_content='1. 保修申请（手动核准）  ................................ ................................ ................................  21 \n2. 单号分配  ................................ ................................ ................................ ........................  22 \n3. 单号提交  ................................ ................................ ................................ ........................  23 \n4. 进度追踪  ................................ ................................ ................................ ........................  23', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 1}),
#   -8.417402267456055),
#  (Document(page_content='5. 保修判定  ................................ ................................ ................................ ........................  10 \n保修设定  ................................ ................................ ................................ ................................ . 11 \n1. 定义产品 (整机料号信息 ) ................................ ................................ ............................  11 \n2. 定义部件（备品料号信息）  ................................ ................................ ........................  17 \n3. 产品保修（维修服务 , “退运流程”设置完成后设置）  ................................ .........  18 \n4. 保修原因  ................................ ................................ ................................ ........................  19 \n保修作业  ................................ ................................ ................................ ................................ . 21 \n1. 保修申请（手动核准）  ................................ ................................ ................................  21', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 1}),
#   -8.008548736572266),
#  (Document(page_content='4.2 结案  \n若厂家在【维修服务】中设定服务中心代结案 , 则不需此步操作；若未设定 , 当服务中\n心结案后 , 厂家需进行结案  \n勾选需结案项目 , 点击【结案】 ,完成结案 ; 下载结案模板 ,点击【上传结案】可批量结\n案;点击【已结案清单】可查看已结案信息', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 23}),
#   -7.599824905395508),
#  (Document(page_content='保修管理 -厂家SOP \n \n \n2022/11/07                                                  WM.1.0     \n 2023/03/17                                                  WM.2.0 \n目录 \n基本资料  ................................ ................................ ................................ ................................ ... 3 \n1. 角色管理  ................................ ................................ ................................ ..........................  3 \n2. 账号管理  ................................ ................................ ................................ ..........................  3 \n客户管理  ................................ ................................ ................................ ................................ ... 5 \n1. 邀请客户  ................................ ................................ ................................ ..........................  5', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 0}),
#   -7.598692893981934),
#  (Document(page_content='1. 邀请客户  ................................ ................................ ................................ ..........................  5 \n2. 关联客户  ................................ ................................ ................................ ..........................  5 \n3. 客户清单  ................................ ................................ ................................ ..........................  6 \n基础设定  ................................ ................................ ................................ ................................ ... 7 \n1. 判定命名  ................................ ................................ ................................ ..........................  7 \n2. 判定逻辑  ................................ ................................ ................................ ..........................  7 \n3. 保修类别  ................................ ................................ ................................ ..........................  9', metadata={'source': 'chinese_pdf/保修管理-廠家sop-repair(去圖標).pdf', 'page': 0}),
#   -6.033951759338379)]

# %%
# 完全相同問候語 l2
vectordb.similarity_search_with_score("早上好", k = vectordb._collection.count(), filter={'category': 'greetings'})
# Out:
# [(Document(page_content='早上好', metadata={'category': 'greetings'}),
#   232.26988220214844),
#  (Document(page_content='一切都好嗎?', metadata={'category': 'greetings'}),
#   509.4013671875),
#  (Document(page_content='你好吗?', metadata={'category': 'greetings'}),
#   518.322021484375),
#  (Document(page_content='很高興認識你', metadata={'category': 'greetings'}),
#   547.3131103515625)]
